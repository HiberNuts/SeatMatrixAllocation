# %%
CourseList = {
    "AD":{ "label": "ARTIFICIAL INTELLIGENCE AND DATA SCIENCE", "value": "AD" },
    "AE":{ "label": "AERONAUTICAL ENGINEERING", "value": "AE" },
    "AG":{ "label": "AGRICULTURAL ENGINEERING", "value": "AG" },
    "AL":{ "label": "Artificial Intelligence and Machine Learning", "value": "AL" },
    "AM":{ "label": "COMPUTER SCIENCE AND ENGINEERING (ARTIFICIAL INTELLIGENCE AND MACHINE LEARNING)", "value": "AM" },
    "AO":{ "label": "AEROSPACE ENGINEERING", "value": "AO" },
    "AU":{ "label": "AUTOMOBILE ENGINEERING", "value": "AU" },
    "BC":{ "label": "Bio Technology and Bio Chemical Engineering", "value": "BC" },
    "BM":{ "label": "BIO MEDICAL ENGINEERING ", "value": "BM" },
    "BP":{ "label": "B.Plan", "value": "BP" },
    "BT":{ "label": "BIO TECHNOLOGY", "value": "BT" },
    "CB":{ "label": "COMPUTER SCIENCE AND BUSSINESS SYSTEM", "value": "CB" },
    "CD":{ "label": "COMPUTER SCIENCE AND DESIGN", "value": "CD" },
    "CE":{ "label": "CIVIL  ENGINEERING ", "value": "CE" },
    "CF":{ "label": "COMPUTER SCIENCE AND ENGINEERING (DATA SCIENCE)", "value": "CF" },
    "CH":{ "label": "CHEMICAL  ENGINEERING ", "value": "CH" },
    "CI":{ "label": "Computer Science and Engineering (Internet of Things)", "value": "CI" },
    "CJ":{ "label": "M.Tech. Computer Science and Engineering (Integrated 5 years)", "value": "CJ" },
    "CO":{ "label": "COMPUTER AND  COMMUNICATION ENGINEERING", "value": "CO" },
    "CS":{ "label": "COMPUTER SCIENCE AND ENGINEERING", "value": "CS" },
    "CT":{ "label": "COMPUTER TECHNOLOGY", "value": "CT" },
    "CY":{ "label": "Cyber Security", "value": "CY" },
    "CZ":{ "label": "CIVIL AND STRUCTUTURAL ENGINEERING", "value": "CZ" },
    "EC":{ "label": "ELECTRONICS AND COMMUNICATION ENGINEERING", "value": "EC" },
    "EE":{ "label": "ELECTRICAL AND ELECTRONICS ENGINEERING", "value": "EE" },
    "EI":{ "label": "ELECTRONICS AND INSTRUMENTATION ENGINEERING", "value": "EI" },
    "EN":{ "label": "ENVIRONMENTAL ENGINEERING", "value": "EN" },
    "ET":{ "label": "ELECTRONICS AND  TELECOMMUNICATION ENGINEERING", "value": "ET" },
    "FD":{ "label": "FOOD TECHNOLOGY ", "value": "FD" },
    "FT":{ "label": "FASHION TECHNOLOGY", "value": "FT" },
    "GI":{ "label": "GEO INFORMATICS", "value": "GI" },
    "HT":{ "label": "HANDLOOM AND TEXTILE TECHNOLOGY", "value": "HT" },
    "IB":{ "label": "INDUSTRIAL BIO TECHNOLOGY", "value": "IB" },
    "IC":{ "label": "INSTRUMENTATION AND CONTROL ENGINEERING", "value": "IC" },
    "IE":{ "label": "INDUSTRIAL ENGINEERING", "value": "IE" },
    "IN":{ "label": "INDUSTRIAL ENGINEERING AND MANAGEMENT", "value": "IN" },
    "IT":{ "label": "INFORMATION TECHNOLOGY", "value": "IT" },
    "LE":{ "label": "LEATHER TECHNOLOGY", "value": "LE" },
    "MC":{ "label": "MECHATRONICS", "value": "MC" },
    "MD":{ "label": "MEDICAL ELECTRONICS ENGINEERING", "value": "MD" },
    "ME":{ "label": "MECHANICAL ENGINEERING", "value": "ME" },
    "MH":{ "label": "MECHANICAL ENGINEERING (SANDWICH)", "value": "MH" },
    "MI":{ "label": "MINING ENGINEERING", "value": "MI" },
    "MM":{ "label": "MECHANICAL ENGINEERING (MANUFACTURING)", "value": "MM" },
    "MN":{ "label": "MANUFACTURING ENGINEERING", "value": "MN" },
    "MO":{ "label": "Mechanical and Mechatronics Engineering (Additive Manufacturing)", "value": "MO" },
    "MR":{ "label": "MARINE ENGINEERING", "value": "MR" },
    "MT":{ "label": "METALLURGICAL ENGINEERING", "value": "MT" },
    "MU":{ "label": "MECHANICAL AND AUTOMATION ENGINEERING", "value": "MU" },
    "MZ":{ "label": "Mechatronics Engineering", "value": "MZ" },
    "PA":{ "label": "PLASTIC TECHNOLOGY", "value": "PA" },
    "PC":{ "label": "PETRO CHEMICAL TECHNOLOGY", "value": "PC" },
    "PD":{ "label": "PETRO CHEMICAL ENGINEERING", "value": "PD" },
    "PE":{ "label": "PETROLEUM ENGINEERING", "value": "PE" },
    "PH":{ "label": "PHARMACEUTICAL TECHNOLOGY", "value": "PH" },
    "PR":{ "label": "PRODUCTION ENGINEERING", "value": "PR" },
    "PT":{ "label": "PRINTING AND PACKING TECHNOLOGY", "value": "PT" },
    "RM":{ "label": "ROBOTICS AND AUTOMATION", "value": "RM" },
    "RP":{ "label": "RUBBER AND PLASTIC TECHNOLOGY", "value": "RP" },
    "SB": {
      "label": "Computer Science and Engineering (Internet of Things and Cyber Security including Block Chain Technology)",
      "value": "SB",
    },
    "SC":{ "label": "Computer Science and Engineering (Cyber Security)", "value": "SC" },
    "SE":{ "label": "Information Science and Engineering", "value": "SE" },
    "SF":{ "label": "Safety and Fire Engineering", "value": "SF" },
    "TC":{ "label": "TEXTILE CHEMISTRY", "value": "TC" },
    "TS":{ "label": "Computer Science and Technology", "value": "TS" },
    "TX":{ "label": "TEXTILE TECHNOLOGY", "value": "TX" },
    "XC":{ "label": "CIVIL ENGINEERING (TAMIL MEDIUM)", "value": "XC" },
    "XM":{ "label": "MECHANICAL ENGINEERING (TAMIL MEDIUM)", "value": "XM" },
    "XS":{ "label": "COMPUTER SCIENCE AND ENGINEERING (TAMIL)", "value": "XS" },
"AP":{ "label": "APPAREL TECHNOLOGY (SS)", "value": "AP" },
"AS":{ "label": "AUTOMOBILE ENGINEERING (SS)", "value": "AS" },
"AT":{ "label": "ARTIFICIAL INTELLIGENCE AND DATA SCIENCE (SS)", "value": "AT" },
"BS":{ "label": "BIO TECHNOLOGY (SS)", "value": "BS" },
"BY":{ "label": "BIO MEDICAL ENGINEERING  (SS)", "value": "BY" },
"CC":{ "label": "CHEMICAL AND ELECTRO CHEMICAL  ENGINEERING (SS)", "value": "CC" },
"CG":{ "label": "Computer Science and Engineering (Artificial Intelligence and Machine Learning) (SS)", "value": "CG" },
"CL":{ "label": "CHEMICAL  ENGINEERING (SS)", "value": "CL" },
"CM":{ "label": "COMPUTER SCIENCE AND ENGINEERING (SS)", "value": "CM" },
"CN":{ "label": "CIVIL  ENGINEERING (SS)", "value": "CN" },
"CR":{ "label": "CERAMIC TECHNOLOGY (SS)", "value": "CR" },
"CW":{ "label": "Computer Science and Business System (SS)", "value": "CW" },
"EM":{ "label": "ELECTRONICS AND COMMUNICATION ENGINEERING (SS)", "value": "EM" },
"ES":{ "label": "ELECTRICAL AND ELECTRONICS (SANDWICH) (SS)", "value": "ES" },
"EY":{ "label": "ELECTRICAL AND ELECTRONICS ENGINEERING (SS)", "value": "EY" },
"FS":{ "label": "FOOD TECHNOLOGY (SS)", "value": "FS" },
"FY":{ "label": "FASHION TECHNOLOGY (SS)", "value": "FY" },
"IM":{ "label": "INFORMATION TECHNOLOGY (SS)", "value": "IM" },
"IS":{ "label": "INDUSTRIAL BIO TECHNOLOGY (SS)", "value": "IS" },
"IY":{ "label": "INSTRUMENTATION AND CONTROL ENGINEERING (SS)", "value": "IY" },
"MA":{ "label": "MATERIAL SCIENCE AND ENGINEERING (SS)", "value": "MA" },
"MF":{ "label": "MECHANICAL ENGINEERING (SS)", "value": "MF" },
"MG":{ "label": "MECHATRONICS (SS)", "value": "MG" },
"MS":{ "label": "MECHANICAL ENGINEERING (SANDWICH) (SS)", "value": "MS" },
"MY":{ "label": "METALLURGICAL ENGINEERING (SS)", "value": "MY" },
"PM":{ "label": "PHARMACEUTICAL TECHNOLOGY (SS)", "value": "PM" },
"PN":{ "label": "PRODUCTION ENGINEERING (SS)", "value": "PN" },
"PP":{ "label": "PETROLEUM ENGINEERING AND TECHNOLOGY (SS)", "value": "PP" },
"PS":{ "label": "PRODUCTION ENGINEERING (SANDWICH) (SS)", "value": "PS" },
"RA":{ "label": "ROBOTICS AND AUTOMATION (SS)", "value": "RA" },
"TT":{ "label": "TEXTILE TECHNOLOGY (SS)", "value": "TT" }
}

# %%
f=open("data.csv")
f=f.readlines()
f=[a.replace("\n", "").split(",") for a in f]
for each in f:
    print({  "courseName":
       CourseList[each[0]],
    "courseCode": each[0],
    "accredation": {
        "value": "ACC",
        "label": "Accredited",
        "disabled": False
    },
    "intake": int(each[1]),
    "Govt": int(each[2]),
    "Surrender": 0,
    "Management": int(each[3]),
    "SWS": int(each[4]),
    "Quota": 1,
    "Added": 0,
    "Pending": 0,
    "error": False
})
# Out:
# {'courseName': {'label': 'AERONAUTICAL ENGINEERING', 'value': 'AE'}, 'courseCode': 'AE', 'accredation': {'value': 'ACC', 'label': 'Accredited', 'disabled': False}, 'intake': 60, 'Govt': 59, 'Surrender': 0, 'Management': 1, 'SWS': 59, 'Quota': 1, 'Added': 0, 'Pending': 0, 'error': False}
# {'courseName': {'label': 'ARTIFICIAL INTELLIGENCE AND DATA SCIENCE (SS)', 'value': 'AT'}, 'courseCode': 'AT', 'accredation': {'value': 'ACC', 'label': 'Accredited', 'disabled': False}, 'intake': 60, 'Govt': 60, 'Surrender': 0, 'Management': 0, 'SWS': 60, 'Quota': 1, 'Added': 0, 'Pending': 0, 'error': False}
# {'courseName': {'label': 'AUTOMOBILE ENGINEERING', 'value': 'AU'}, 'courseCode': 'AU', 'accredation': {'value': 'ACC', 'label': 'Accredited', 'disabled': False}, 'intake': 60, 'Govt': 59, 'Surrender': 0, 'Management': 1, 'SWS': 59, 'Quota': 1, 'Added': 0, 'Pending': 0, 'error': False}
# ...
